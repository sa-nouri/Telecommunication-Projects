# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
import h5py
import numpy as np
import pandas as pd

# %%
path_ds = "VNAT_Dataframe_release_1.h5"
df = pd.read_hdf(path_ds)

# %%
f = h5py.File(path_ds, "r")

# %%
for key in f.keys():
    print(key)
    print(type(f[key]))

# %%
group = f[key]

for key in group.keys():
    print(key)

data1 = group["axis0"][()]
data2 = group["axis1"][()]
data3 = group["block0_items"][()]
data4 = group["block0_values"][()]
f.close()

# %%
data1

# %%
data2.shape

# %%
data3

# %%
data4[0].shape
